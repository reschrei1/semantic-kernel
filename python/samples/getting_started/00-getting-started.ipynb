# %% [markdown]
# # Setup
#
# **Step 1**: Import Semantic Kernel SDK from pypi.org

# %%
# !python -m pip install semantic-kernel==0.9.8b1
# Out:
# Collecting semantic-kernel==0.9.8b1
#   Downloading semantic_kernel-0.9.8b1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiohttp<4.0,>=3.8 (from semantic-kernel==0.9.8b1)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from semantic-kernel==0.9.8b1)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting grpcio>=1.50.0 (from semantic-kernel==0.9.8b1)
#   Downloading grpcio-1.63.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting jinja2<4.0.0,>=3.1.3 (from semantic-kernel==0.9.8b1)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting motor<4.0.0,>=3.3.2 (from semantic-kernel==0.9.8b1)
#   Downloading motor-3.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /home/azureuser/environment/semantic-kernel/.venv/lib/python3.10/site-packages (from semantic-kernel==0.9.8b1) (1.6.0)
# Collecting numpy>=1.25 (from semantic-kernel==0.9.8b1)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.3 MB/s eta 0:00:00
# Collecting openai>=1.0 (from semantic-kernel==0.9.8b1)
#   Downloading openai-1.29.0-py3-none-any.whl.metadata (21 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel==0.9.8b1)
#   Downloading openapi_core-0.19.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting prance<24.0.0.0,>=23.6.21.0 (from semantic-kernel==0.9.8b1)
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4<0.10.0,>=0.9.13 (from semantic-kernel==0.9.8b1)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydantic<3,>=2 (from semantic-kernel==0.9.8b1)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 7.6 MB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.1 (from semantic-kernel==0.9.8b1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting regex<2024.0.0,>=2023.6.3 (from semantic-kernel==0.9.8b1)
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.9 MB/s eta 0:00:00
# Collecting scipy>=1.5.0 (from semantic-kernel==0.9.8b1)
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.8b1)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.3->semantic-kernel==0.9.8b1)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pymongo<5,>=4.5 (from motor<4.0.0,>=3.3.2->semantic-kernel==0.9.8b1)
#   Downloading pymongo-4.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/azureuser/environment/semantic-kernel/.venv/lib/python3.10/site-packages (from openai>=1.0->semantic-kernel==0.9.8b1) (4.11.0)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading jsonschema_path-0.3.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading openapi_schema_validator-0.6.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting chardet>=3.0 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting requests>=2.25 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six~=1.15 in /home/azureuser/environment/semantic-kernel/.venv/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /home/azureuser/environment/semantic-kernel/.venv/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1) (24.0)
# Collecting PyMeta3>=0.5.1 (from pybars4<0.10.0,>=0.9.13->semantic-kernel==0.9.8b1)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->semantic-kernel==0.9.8b1)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=2->semantic-kernel==0.9.8b1)
#   Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/azureuser/environment/semantic-kernel/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==0.9.8b1) (1.2.1)
# Collecting certifi (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.8b1)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading rpds_py-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting PyYAML>=5.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading pathable-0.4.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading referencing-0.31.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.8b1)
#   Downloading lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5,>=4.5->motor<4.0.0,>=3.3.2->semantic-kernel==0.9.8b1)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.8b1)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Downloading semantic_kernel-0.9.8b1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.7 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.5 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading grpcio-1.63.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 83.9 MB/s eta 0:00:00:00:01
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 8.5 MB/s eta 0:00:00
# Downloading motor-3.4.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 6.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 55.9 MB/s eta 0:00:00:00:0100:01
# Downloading openai-1.29.0-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.3/320.3 kB 17.5 MB/s eta 0:00:00
# Downloading openapi_core-0.19.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 8.3 MB/s eta 0:00:00
# Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 26.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 63.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 kB 35.2 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 22.8 MB/s eta 0:00:00:00:0100:01
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 5.4 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.9 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 15.4 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 18.7 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.6 MB/s eta 0:00:00
# Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 5.1 MB/s eta 0:00:00
# Downloading jsonschema_path-0.3.2-py3-none-any.whl (14 kB)
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 10.0 MB/s eta 0:00:00
# Downloading openapi_schema_validator-0.6.2-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Downloading pymongo-4.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 33.5 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.2 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 9.2 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.4 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 19.5 MB/s eta 0:00:00
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.9 MB/s eta 0:00:00
# Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 13.6 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 10.6 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 11.7 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 21.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 kB 5.4 MB/s eta 0:00:00
# Downloading pathable-0.4.3-py3-none-any.whl (9.6 kB)
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 36.8 MB/s eta 0:00:00
# Downloading referencing-0.31.1-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.8 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 33.8 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 10.0 MB/s eta 0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (pyproject.toml) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14340 sha256=613eb51e72b7f1a5267f060e33f4ed224b79e005fa09a4c0f43ac8c20ff087d9
#   Stored in directory: /home/azureuser/.cache/pip/wheels/6e/aa/f7/0fca6ca6dabcd593ef782462477b2b5b891f477c407072e30a
#   Building wheel for PyMeta3 (pyproject.toml) ... done
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16448 sha256=71f110a61a02ae5e23ed5c2361fcc591441cfb512e756e739608e88dbf9b8994
#   Stored in directory: /home/azureuser/.cache/pip/wheels/f4/ef/62/1d388a1576d871760164a1388632b29645c3f907cd009d6cb1
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, urllib3, tqdm, sniffio, ruamel.yaml.clib, rpds-py, rfc3339-validator, regex, PyYAML, python-dotenv, pydantic-core, pybars4, pathable, numpy, multidict, more-itertools, MarkupSafe, lazy-object-proxy, isodate, idna, h11, grpcio, frozenlist, dnspython, distro, defusedxml, charset-normalizer, chardet, certifi, attrs, async-timeout, annotated-types, yarl, werkzeug, scipy, ruamel.yaml, requests, referencing, pymongo, pydantic, jinja2, httpcore, anyio, aiosignal, prance, motor, jsonschema-specifications, jsonschema-path, httpx, aiohttp, openai, jsonschema, openapi-schema-validator, openapi-spec-validator, openapi_core, semantic-kernel
# Successfully installed MarkupSafe-2.1.5 PyMeta3-0.5.1 PyYAML-6.0.1 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.3.0 async-timeout-4.0.3 attrs-23.2.0 certifi-2024.2.2 chardet-5.2.0 charset-normalizer-3.3.2 defusedxml-0.7.1 distro-1.9.0 dnspython-2.6.1 frozenlist-1.4.1 grpcio-1.63.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 isodate-0.6.1 jinja2-3.1.4 jsonschema-4.22.0 jsonschema-path-0.3.2 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 more-itertools-10.2.0 motor-3.4.0 multidict-6.0.5 numpy-1.26.4 openai-1.29.0 openapi-schema-validator-0.6.2 openapi-spec-validator-0.7.1 openapi_core-0.19.1 parse-1.20.1 pathable-0.4.3 prance-23.6.21.0 pybars4-0.9.13 pydantic-2.7.1 pydantic-core-2.18.2 pymongo-4.7.2 python-dotenv-1.0.1 referencing-0.31.1 regex-2023.12.25 requests-2.31.0 rfc3339-validator-0.1.4 rpds-py-0.18.1 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 scipy-1.13.0 semantic-kernel-0.9.8b1 sniffio-1.3.1 tqdm-4.66.4 urllib3-2.2.1 werkzeug-3.0.3 yarl-1.9.4

# %%
from semantic_kernel import Kernel

kernel = Kernel()

# %% [markdown]
# ### Configure the service you'd like to use via the `Service` Enum.

# %%
from services import Service

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = Service.AzureOpenAI

# %% [markdown]
# ## Option 1: using OpenAI
#
# **Step 2**: Add your [OpenAI Key](https://openai.com/product/) key to a `.env` file in the same folder (org Id only if you have multiple orgs):
#
# ```
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# ```
#
# Use "keyword arguments" to instantiate an OpenAI Chat Completion service and add it to the kernel:
#
# ## Option 2: using Azure OpenAI
#
# **Step 2**: Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to a `.env` file in the same folder:
#
# ```
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_DEPLOYMENT_NAME="..."
# ```
#
# Use "keyword arguments" to instantiate an Azure OpenAI Chat Completion service and add it to the kernel:

# %%
from semantic_kernel.utils.settings import azure_openai_settings_from_dot_env, openai_settings_from_dot_env

service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    api_key, org_id = openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(service_id=service_id, ai_model_id="gpt-3.5-turbo-1106", api_key=api_key, org_id=org_id),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    deployment, api_key, endpoint = azure_openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(service_id=service_id, deployment_name=deployment, endpoint=endpoint, api_key=api_key),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.add_plugin(parent_directory="../../../prompt_template_samples/", plugin_name="FunPlugin")

# %%
from semantic_kernel.functions import KernelArguments

joke_function = plugin["Joke"]

joke = await kernel.invoke(joke_function, KernelArguments(input="time travel to dinosaur age", style="super silly"))
print(joke)
# Out:
# Why don't you ever want to play hide and seek with a time traveler?
#
# Because if they hide in the dinosaur age, you'll have a T-Rex of a time finding them!
